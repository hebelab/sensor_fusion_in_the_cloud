# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import PG.PG as PG

# %%
image_file = 'image/baboon.png'

image = Image.open(image_file).convert('L')
x = np.asarray(image)

# %%
X = np.fft.fftshift(np.fft.fft2(x))
inv = np.fft.ifft2(X)
plt.imshow(abs(inv))

# %%
m = 8;  # downsampling coefficient
y = x[::m, ::m]  # input LR image

# %%
plt.imshow(y)

# %%
z = np.zeros(x.shape, dtype=int)
z[::m, ::m] = y

# %%
plt.imshow(z)

# %%
gt_mean = x.mean()

pg_image = np.real(PG.pg(z, m, 0.5, gt_mean))
plt.imshow(pg_image)
